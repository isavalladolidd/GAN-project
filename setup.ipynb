# %%
import os

# Ruta local del proyecto
PROJECT_DIR = os.path.dirname(os.path.abspath("__file__"))
VITS2_DIR = os.path.join(PROJECT_DIR, "vits2")

# Limpiar si existe
if os.path.exists(VITS2_DIR):
    import shutil
    shutil.rmtree(VITS2_DIR)

print("Clonando repositorio oficial...")
os.system(f"git clone https://github.com/daniilrobnikov/vits2.git {VITS2_DIR} -q")

print("✓ VITS2 clonado en:", VITS2_DIR)
# Out:
# Clonando repositorio oficial...
# ✓ VITS2 clonado en: /Users/isabelvalladolid/Documents/DeepLearningProjects/GAN-project/vits2

# %%
import sys

sys.path.insert(0, VITS2_DIR)

print("✓ VITS2 agregado al path de Python:", VITS2_DIR)
# Out:
# ✓ VITS2 agregado al path de Python: /Users/isabelvalladolid/Documents/DeepLearningProjects/GAN-project/vits2
